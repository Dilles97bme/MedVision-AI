# %% [markdown]
# # Section 1
#
# ## Import Required Libraries
#
# ### Objective
#
# Import only the libraries required for preprocessing.
#
# Unlike previous notebooks, we now begin using PyTorch because we are preparing images for deep learning models.

# %%
from pathlib import Path

import numpy as np
import matplotlib.pyplot as plt

from PIL import Image

import torch
from torchvision import transforms

# %% [markdown]
# # Section 2
#
# ## Load a Sample Image
#
# We use one image to understand how every preprocessing step changes the data before applying the same pipeline to the entire dataset.

# %%
DATASET_PATH = Path(r"C:\MedVision-AI\dataset\chest_xray")

sample_path = next(
    (DATASET_PATH / "train" / "NORMAL").glob("*.jpeg")
)

image = Image.open(sample_path)

image

# %%
plt.figure(figsize=(5,5))

plt.imshow(image,cmap="gray")

plt.title("Original Image")

plt.axis("off")

plt.show()

# %% [markdown]
# # Section 3   RGB ConversioNEfficientNet expects
#
# 224×224×3
